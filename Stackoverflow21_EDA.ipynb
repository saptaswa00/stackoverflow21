# %% [markdown]
# # Exploratory Data Analysis of Stack-overflow 2021 using Python
#                                                                                              - Saptaswa Basu

# %% [markdown]
# ![stackoverflow21.img.png](attachment:stackoverflow21.img.png)

# %% [markdown]
# ##### `The objective` of this project is to analyzing the responses of developers from stack-overflow 2021 developer survey

# %% [markdown]
# ##### Some insightful graphical representations from the project has been shown below :

# %%
# Collage of some interesting graphs
.
.
.
.
.
.
.
.
.

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this project we are going to analyze the dataset from Stackoverflow Developer Survey 2021. We have used some of the python library to analyze and visualize the data , primarily we are going to use `NumPy` , `Pandas` webframe for analyzing purpose also `MatplotLib` and `Seaborn` for visualization purpose.

# %% [markdown]
# The dataset we have used in this project has been taken from the official Stackoverflow website: https://insights.stackoverflow.com/survey.

# %% [markdown]
# There are several ways to getting dataset into jupyter, here we are gonna download the CSV manually and upload it via Jupyter's GUI.

# %% [markdown]
# ##### This project has been performed using real world dataset's, so `Data Cleaning` and `Data Preparation` is one of the major part of this project.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import os

# %%
os.listdir('stack-overflow-developer-survey-2021')
# Out:
# ['README_2021.txt',
#  'so_survey_2021.pdf',
#  'survey_results_public.csv',
#  'survey_results_schema.csv']

# %%
stackoverflow21_df = pd.read_csv('stack-overflow-developer-survey-2021/survey_results_public.csv')

# %%
stackoverflow21_df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %% [markdown]
# There are around 83000+ rows and 48 coloums in this dataset where those columns represents `questions asked` in the survey and the rows represents the `answers` of those questions by respondents.

# %%
stackoverflow21_df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
stackoverflow21_df['Language'] = stackoverflow21_df.LanguageWantToWorkWith
stackoverflow21_df['Database'] = stackoverflow21_df.DatabaseHaveWorkedWith
stackoverflow21_df['Platform'] = stackoverflow21_df.PlatformHaveWorkedWith
stackoverflow21_df['Webframe'] = stackoverflow21_df.WebframeHaveWorkedWith
stackoverflow21_df['ToolsTech'] = stackoverflow21_df.ToolsTechHaveWorkedWith
stackoverflow21_df['MiscTech'] = stackoverflow21_df.MiscTechHaveWorkedWith
stackoverflow21_df['CompTotal'] = stackoverflow21_df.ConvertedCompYearly

# %%
stackoverflow21_df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
schema_df='stack-overflow-developer-survey-2021/survey_results_schema.csv'

# %%
stackoverflow21_schema = pd.read_csv(schema_df,index_col='qname')
stackoverflow21_schema.head(10)
# Out:
#                qid                                           question  \
# qname
# S0           QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo     QID12                                  Browser Meta Info
# S1            QID1  <span style="font-size:22px; font-family: aria...
# MainBranch    QID2  Which of the following options best describes ...
# Employment   QID24  Which of the following best describes your cur...
# Country       QID6  Where do you live? <span style="font-weight: b...
# US_State      QID7  <p>In which state or territory of the USA do y...
# UK_Country    QID9  In which part of the United Kingdom do you liv...
# S2          QID190  <span style="font-size:22px; font-family: aria...
# EdLevel      QID25  Which of the following best describes the high...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# MetaInfo         False  Meta  Browser
# S1               False    DB       TB
# ...

# %%
stackoverflow21_schema.drop(columns=['qid','force_resp','type','selector'],inplace=True)

# %%
stackoverflow21_schema.head(10)
# Out:
#                                                      question
# qname
# S0          <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo                                    Browser Meta Info
# S1          <span style="font-size:22px; font-family: aria...
# MainBranch  Which of the following options best describes ...
# Employment  Which of the following best describes your cur...
# Country     Where do you live? <span style="font-weight: b...
# US_State    <p>In which state or territory of the USA do y...
# UK_Country  In which part of the United Kingdom do you liv...
# S2          <span style="font-size:22px; font-family: aria...
# EdLevel     Which of the following best describes the high...

# %%
schema_qs = stackoverflow21_schema.question
schema_qs.head()
# Out:
# qname
# S0            <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo                                      Browser Meta Info
# S1            <span style="font-size:22px; font-family: aria...
# MainBranch    Which of the following options best describes ...
# Employment    Which of the following best describes your cur...
# Name: question, dtype: object

# %%
schema_qs['Accessibility']
# Out:
# 'Which of the following describe you, if any? Please check all that apply. '

# %% [markdown]
#  ## Data Preparation & cleaning

# %% [markdown]
# As we know any real world dataset contains lots of unnecessary data's,so before we make a proper analysis we need to prepare data's and also need to clean some of not so essencial data points.

# %% [markdown]
# Here we are focusing on some areas to look upon:

# %% [markdown]
#    - Undertanding the demographics of the survey respondents & global programming community
#    - Distribution of programming skills, experience and preferences
#    - Employment related information,preferences & opinions.

# %%
selected_qname = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    # Programming experience
    'Age1stCode',
    'LearnCode',
    'YearsCode',
    'YearsCodePro',
    'Language',              
    'Database',              
    'Platform',              
    'Webframe',              
    'MiscTech',              
    'ToolsTech', 
    'NEWStuck',
    'NEWSOSites',
    # Employment
    'Employment',
    'DevType',
    'CompTotal',
    'OpSys'
]

# %%
len(selected_qname)
# Out:
# 20

# %% [markdown]
# Below we made a copy of our main two datasets, so that in case of any discripency we can get back to our real datasets.

# %%
stackoverflow21 = stackoverflow21_df[selected_qname].copy()

# %%
schema21 = schema_qs[selected_qname]

# %%
stackoverflow21.shape
# Out:
# (83439, 20)

# %%
stackoverflow21
# Out:
#                                                  Country              Age  \
# 0                                               Slovakia  25-34 years old
# 1                                            Netherlands  18-24 years old
# 2                                     Russian Federation  18-24 years old
# 3                                                Austria  35-44 years old
# 4      United Kingdom of Great Britain and Northern I...  25-34 years old
# ...                                                  ...              ...
# 83434                           United States of America  25-34 years old
# 83435                                              Benin  18-24 years old
# 83436                           United States of America  25-34 years old
# 83437                                             Canada  25-34 years old
# 83438                                             Brazil  18-24 years old
#
#       Gender                                            EdLevel  \
# ...

# %%
stackoverflow21['Age'] = stackoverflow21['Age'].str.extract('(\d\d)',expand = True)

# %%
stackoverflow21['Age1stCode'] = stackoverflow21['Age1stCode'].str.extract('(\d\d - \d\d)',expand = True)

# %% [markdown]
# Above we use the `str.extract` function to extract only numercal data from the string datatypes. The numerical digits denotes as `\d` in the above expression.

# %%
stackoverflow21
# Out:
#                                                  Country Age Gender  \
# 0                                               Slovakia  25    Man
# 1                                            Netherlands  18    Man
# 2                                     Russian Federation  18    Man
# 3                                                Austria  35    Man
# 4      United Kingdom of Great Britain and Northern I...  25    Man
# ...                                                  ...  ..    ...
# 83434                           United States of America  25    Man
# 83435                                              Benin  18    Man
# 83436                           United States of America  25    Man
# 83437                                             Canada  25    Man
# 83438                                             Brazil  18    Man
#
#                                                  EdLevel Age1stCode  \
# 0      Secondary school (e.g. American high school, G...    18 - 24
# ...

# %%
# To change the datatype from object to numeric
stackoverflow21['Age'] = pd.to_numeric(stackoverflow21.Age, errors = 'coerce')
stackoverflow21['YearsCode'] = pd.to_numeric(stackoverflow21.YearsCode, errors = 'coerce')
stackoverflow21['YearsCodePro'] = pd.to_numeric(stackoverflow21.YearsCodePro, errors = 'coerce')

# %%
# After using this line the not-null value become 0 for Age1stCode, may be because there is range given at Age1stCode column
# stackoverflow21['Age1stCode'] = pd.to_numeric(stackoverflow21.Age1stCode, errors = 'coerce')

# %%
stackoverflow21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       83439 non-null  object
#  1   Age           81832 non-null  float64
#  2   Gender        82286 non-null  object
#  3   EdLevel       83126 non-null  object
#  4   Age1stCode    70535 non-null  object
#  5   LearnCode     82963 non-null  object
#  6   YearsCode     79982 non-null  float64
#  7   YearsCodePro  58467 non-null  float64
#  8   Language      76821 non-null  object
#  9   Database      69546 non-null  object
#  10  Platform      52135 non-null  object
#  11  Webframe      61707 non-null  object
#  12  MiscTech      47055 non-null  object
#  13  ToolsTech     72537 non-null  object
#  14  NEWStuck      83052 non-null  object
#  15  NEWSOSites    83171 non-null  object
#  16  Employment    83323 non-null  object
#  17  DevType       66484 non-null  object
# ...

# %%
stackoverflow21.describe()
# Out:
#                 Age     YearsCode  YearsCodePro     CompTotal
# count  81832.000000  79982.000000  58467.000000  4.684400e+04
# mean      26.809769     12.485722      9.572511  1.184262e+05
# std        9.276513      9.626184      8.123225  5.272944e+05
# min       18.000000      1.000000      1.000000  1.000000e+00
# 25%       18.000000      5.000000      4.000000  2.702500e+04
# 50%       25.000000     10.000000      7.000000  5.621100e+04
# 75%       35.000000     17.000000     13.000000  1.000000e+05
# max       65.000000     50.000000     50.000000  4.524131e+07

# %%
stackoverflow21['Gender'].value_counts()
# Out:
# Man                                                                                   74817
# Woman                                                                                  4120
# Prefer not to say                                                                      1442
# Non-binary, genderqueer, or gender non-conforming                                       690
# Or, in your own words:                                                                  413
# Man;Or, in your own words:                                                              268
# Man;Non-binary, genderqueer, or gender non-conforming                                   252
# Woman;Non-binary, genderqueer, or gender non-conforming                                 147
# Man;Woman                                                                                41
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:                 21
# ...

# %%
stackoverflow21.where(~(stackoverflow21.Gender.str.contains(';', na = False)), np.nan, inplace = True)

# %% [markdown]
# As it can be seen, In the gender column there are so many rows consist with multiple options and those are separetd with `;` sign , so to remove those unwanted rows we use this line to get more clean column data.

# %%
stackoverflow21['Gender'].value_counts()
# Out:
# Man                                                  74817
# Woman                                                 4120
# Prefer not to say                                     1442
# Non-binary, genderqueer, or gender non-conforming      690
# Or, in your own words:                                 413
# Name: Gender, dtype: int64

# %%
stackoverflow21.sample(10)
# Out:
#                                                  Country   Age Gender  \
# 60820                           United States of America  25.0    Man
# 2287                                              France  18.0    Man
# 30732                           United States of America  55.0    Man
# 79402                                            Germany  25.0    Man
# 50174                                         Bangladesh  35.0    Man
# 57916                                           Pakistan  18.0    Man
# 50272                           United States of America  35.0    Man
# 31930  United Kingdom of Great Britain and Northern I...  35.0    Man
# 42951                                              Italy  25.0  Woman
# 54418                                             France  18.0    Man
#
#                                                  EdLevel Age1stCode  \
# 60820       Bachelor’s degree (B.A., B.S., B.Eng., etc.)    11 - 17
# ...

# %% [markdown]
# ##### We've now cleaned up and prepared the dataset, now its time for explore the data and do analysis of those to get some valuable insights from those data's.

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %% [markdown]
# At the begginig of the analysis we need to look at the demographics of all the representative of the survey in the community worldwide.

# %% [markdown]
# In this analysis for visualization purpose we used **`matplotlib.pyplo`** and **`seaborn`**

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 20
matplotlib.rcParams['figure.figsize'] = (9,5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ## Country

# %%
schema21.Country
# Out:
# 'Where do you live? <span style="font-weight: bolder;">*</span>'

# %%
schema21.Country = 'Where do you live?'
schema21.Country
# Out:
# 'Where do you live?'

# %%
stackoverflow21.Country.nunique()  ## No. of unique countries
# Out:
# 180

# %%
# Replacing big names into small once
stackoverflow21['Country'] = stackoverflow21['Country'].replace("United Kingdom of Great Britain and Northern Ireland", 'UK & Ireland')

# %%
# Country with highest number of respondents
top_countries = stackoverflow21.Country.value_counts().head(15)
top_countries
# Out:
# United States of America                                15051
# India                                                   10476
# Germany                                                  5568
# United Kingdom of Great Britain and Northern Ireland     4447
# Canada                                                   2983
# France                                                   2685
# Brazil                                                   2232
# Poland                                                   1785
# Netherlands                                              1759
# Italy                                                    1659
# Australia                                                1627
# Spain                                                    1472
# Russian Federation                                       1462
# Sweden                                                   1179
# Turkey                                                   1050
# Name: Country, dtype: int64

# %%
plt.figure(figsize = (15,10))
plt.xticks(rotation = 80)
plt.title(schema21.Country)
sns.barplot(y = top_countries.index, x = top_countries);

# %% [markdown]
# ##### As from the visualization we can say that most number of respondents are from US and INDIA, that probably due to the language of the survey ,as the survey is in English so the highest portion of respondents are from English speaking countries.

# %% [markdown]
# ## Age

# %%
schema21.Age
# Out:
# 'What is your age?'

# %%
sns.countplot(x = stackoverflow21.Age);

# %%
plt.figure(figsize = (12,6))
plt.title(schema21.Age)
plt.xlabel('Age')
plt.ylabel('Number of respondents')
plt.hist(stackoverflow21.Age, bins = np.arange(10,80,10), color ='Blue');

# %% [markdown]
# ##### From this above visualization we can conclude that 20-30 years are the age which mainly represents the CS comunity in a wide numbers and also people started working in such domains from very young age.
#
# ##### Also from the data we can say that most percentage of respondents are from 18-40 years old.

# %% [markdown]
# ## Age1stCode

# %%
schema21.Age1stCode
# Out:
# 'At what age did you write your first line of code or program? (e.g., webpage, Hello World, Scratch project) '

# %%
# droping all the NAN values
code1st = stackoverflow21['Age1stCode'].dropna().copy()
code1st
# Out:
# 0        18 - 24 years
# 1        11 - 17 years
# 2        11 - 17 years
# 3        11 - 17 years
# 4         5 - 10 years
#              ...
# 83434    11 - 17 years
# 83435    11 - 17 years
# 83436    11 - 17 years
# 83437    11 - 17 years
# 83438    11 - 17 years
# Name: Age1stCode, Length: 83243, dtype: object

# %%
code1st_df = pd.DataFrame(code1st.value_counts()).reset_index()
code1st_df
# Out:
#                   index  Age1stCode
# 0         11 - 17 years       44170
# 1         18 - 24 years       20065
# 2          5 - 10 years       11720
# 3         25 - 34 years        4199
# 4         35 - 44 years        1312
# 5  Younger than 5 years         905
# 6         45 - 54 years         544
# 7         55 - 64 years         245
# 8   Older than 64 years          83

# %%
code1st_df.columns = ['Age1stCode', 'Responses']
code1st_df
# Out:
#              Age1stCode  Responses
# 0         11 - 17 years      44170
# 1         18 - 24 years      20065
# 2          5 - 10 years      11720
# 3         25 - 34 years       4199
# 4         35 - 44 years       1312
# 5  Younger than 5 years        905
# 6         45 - 54 years        544
# 7         55 - 64 years        245
# 8   Older than 64 years         83

# %%
plt.figure(figsize = (18,8))
plt.xticks(rotation = 80)
sns.barplot(x = code1st_df.Age1stCode , y = code1st_df.Responses);

# %% [markdown]
# ## Working Experience by years

# %%
plt.figure(figsize = (20, 6))
sns.histplot(x = stackoverflow21["YearsCode"], color = "purple", bins=30, kde=True);

# %%
plt.figure(figsize = (20,6))
sns.histplot(x = stackoverflow21.YearsCodePro ,  bins = 30 , kde=True);

# %% [markdown]
# ##### As per the graph most of the respondents have around `5-15 years` of coding experience in general and in `professional career` mostly they have around `1-10 years` of experience in coding on an average.

# %% [markdown]
# ## Gender

# %%
schema21.Gender
# Out:
# 'Which of the following describe you, if any? Please check all that apply.'

# %%
gender_counts = stackoverflow21.Gender.value_counts()
gender_counts
# Out:
# Man                                                  74817
# Woman                                                 4120
# Prefer not to say                                     1442
# Non-binary, genderqueer, or gender non-conforming      690
# Or, in your own words:                                 413
# Name: Gender, dtype: int64

# %%
plt.figure(figsize = (30,10))
matplotlib.rcParams['font.size'] = 12
plt.title("Gender Distribution")
plt.pie(gender_counts, labels = gender_counts.index, autopct = '%1.1f%%', startangle = 180);

# %% [markdown]
# ##### As we know the average number of women and non-biary gender in programming comunity is around 12% and here it shows around 8%. So, the number of respondents is lower than the average number also out of those around 2% of people doesnot prefer to mentioned their gender.

# %%
# Gender vs Age representation of respondents
sns.barplot(x = stackoverflow21.Age , y = stackoverflow21.Gender);

# %% [markdown]
# ##### Here, we represents the `average age of each gender` and came to a conclution that on an average the age of all combined is around 26 years , womens age is around 25 and mens age around 26-27 on an average.

# %% [markdown]
# ## Education Level

# %%
schema21.EdLevel
# Out:
# 'Which of the following best describes the highest level of formal education that you’ve completed? *'

# %%
stackoverflow21.EdLevel
# Out:
# 0        Secondary school (e.g. American high school, G...
# 1             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#                                ...
# 83434         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436    Secondary school (e.g. American high school, G...
# 83437         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438                   Professional degree (JD, MD, etc.)
# Name: EdLevel, Length: 83439, dtype: object

# %%
plt.figure(figsize = (12,6))
sns.countplot(y=stackoverflow21.EdLevel)
plt.xticks(rotation=80)
plt.title(schema21.EdLevel);

# %% [markdown]
# ##### It appears from the plot that most of the respondents or almost half of them have a degree in either Bachelor's or Master's, so it seems most programmers have some sort of higher level college education.

# %% [markdown]
# ## Employment

# %%
schema21.Employment
# Out:
# 'Which of the following best describes your current employment status?'

# %%
schema21.Employment = 'Which of the following best describes your current employment status?'
schema21.Employment
# Out:
# 'Which of the following best describes your current employment status?'

# %%
stackoverflow21.Employment.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Independent contractor, freelancer, or self-em...
# 1                                       Student, full-time
# 2                                       Student, full-time
# 3                                       Employed full-time
# 4        Independent contractor, freelancer, or self-em...
#                                ...
# 83434                                   Employed full-time
# 83435    Independent contractor, freelancer, or self-em...
# 83436                                   Employed full-time
# 83437                                   Employed full-time
# 83438                                   Employed full-time
# Name: Employment, Length: 83439, dtype: object>

# %%
(stackoverflow21.Employment.value_counts(normalize=True, ascending=True)*100).plot(kind='barh', color='g')
plt.title(schema21.Employment)
plt.xlabel('Percentage');

# %% [markdown]
# ##### As we can see out of all the respondents around 65% are full time employeed and close to 10-12% respondents are works part-time or as a freelancers.

# %% [markdown]
# ## Development Domain

# %%
schema21.DevType
# Out:
# 'Which of the following describes your current job? Please select all that apply.'

# %%
stackoverflow21.DevType.value_counts()
# Out:
# Developer, full-stack                                                                                                                                                                                                                                                                                                                                                                                          8601
# Developer, back-end                                                                                                                                                                                                                                                                                                                                                                                            5467
# ...

# %% [markdown]
# ##### Below we defined a helper function that turns a column containing lists of values (like `stackoverflow21.DevType`) into a data frame with one column for each possible option.

# %%
def split_multicolumn(col_series):
    result_df = col_series.to_frame()
    options = []
    # Iterate over the column
    for idx, value  in col_series[col_series.notnull()].iteritems():
        # Break each value into list of options
        for option in value.split(';'):
            # Add the option as a column to result
            if not option in result_df.columns:
                options.append(option)
                result_df[option] = False
            # Mark the value in the option column as True
            result_df.at[idx, option] = True
    return result_df[options]

# %%
dev_type_df = split_multicolumn(stackoverflow21.DevType)

# %%
dev_type_df.head()
# Out:
#    Developer, mobile  Developer, front-end  \
# 0               True                 False
# 1              False                 False
# 2              False                 False
# 3              False                  True
# 4              False                 False
#
#    Developer, desktop or enterprise applications  Developer, full-stack  \
# 0                                          False                  False
# 1                                          False                  False
# 2                                          False                  False
# 3                                          False                  False
# 4                                           True                   True
#
#    Engineer, data  Other (please specify):  \
# 0           False                    False
# 1           False                    False
# 2           False                    False
# 3           False                    False
# 4            True                     True
#
# ...

# %%
dev_type_totals = dev_type_df.sum().sort_values(ascending=False)
dev_type_totals
# Out:
# Developer, full-stack                            32619
# Developer, back-end                              28817
# Developer, front-end                             18065
# Developer, desktop or enterprise applications    10930
# Developer, mobile                                 9721
# DevOps specialist                                 6975
# System administrator                              5996
# Database administrator                            5594
# Designer                                          4546
# Developer, embedded applications or devices       4536
# Data scientist or machine learning specialist     4221
# Student                                           4127
# Engineer, data                                    4122
# Engineering manager                               3774
# Data or business analyst                          3751
# Developer, QA or test                             3559
# Other (please specify):                           3482
# ...

# %%
plt.figure(figsize = (15,8))
plt.xticks(rotation = 80)
plt.title(schema21.DevType)
sns.barplot(y = dev_type_totals.index, x = dev_type_totals , color = 'orange');

# %% [markdown]
# ##### As we can see from the graphs the stackoverflow is widely used by Full-stack developer, also back-end and front-end developer respondents are also very high.

# %% [markdown]
# ##### Now if we only take the data of Data Scientist and get to know about the percent of respondents, we can get.....

# %%
dev_type_totals.index[10]
# Out:
# 'Data scientist or machine learning specialist'

# %%
total_data_scientist = dev_type_totals[10]
total_data_scientist
# Out:
# 4221

# %%
total_developer = dev_type_totals.sum()
total_developer
# Out:
# 172225

# %%
# Percentage of respondents work in roles rolated to Data Science
(total_data_scientist/total_developer)*100
# Out:
# 2.450863695746843

# %% [markdown]
# ##### Here we can calculate that among all the developers from difference domain , `Data Scientist` respondents are only around 2.5%, which is still more than `Data Engineers` and `Business Analyst` and many more.

# %% [markdown]
# ## Language

# %%
schema21.Language
# Out:
# 'Which <b>programming, scripting, and markup languages</b> have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)'

# %%
schema21.Language = 'Which programming, scripting, and markup languages have you done extensive development work in over the past year?'
schema21.Language
# Out:
# 'Which programming, scripting, and markup languages have you done extensive development work in over the past year?'

# %%
language_type = split_multicolumn(stackoverflow21.Language)

# %%
language_type.head()
# Out:
#    Swift  Julia  Python   Rust  JavaScript  TypeScript  Bash/Shell  HTML/CSS  \
# 0   True  False   False  False       False       False       False     False
# 1  False  False   False  False       False       False       False     False
# 2  False   True    True   True       False       False       False     False
# 3  False  False   False  False        True        True       False     False
# 4  False  False    True  False       False       False        True      True
#
#      SQL     C#  ...  Elixir  PowerShell    VBA  Matlab   LISP  Erlang  \
# 0  False  False  ...   False       False  False   False  False   False
# 1  False  False  ...   False       False  False   False  False   False
# 2  False  False  ...   False       False  False   False  False   False
# 3  False  False  ...   False       False  False   False  False   False
# 4   True  False  ...   False       False  False   False  False   False
#
#    Groovy  Crystal  Delphi  COBOL
# 0   False    False   False  False
# ...

# %%
popular_languages = language_type.sum().sort_values(ascending = False).head(20)
popular_languages
# Out:
# JavaScript    36674
# Python        34556
# HTML/CSS      29057
# TypeScript    26664
# SQL           26375
# Node.js       23901
# C#            17804
# Java          17051
# Rust          15650
# Go            15649
# C++           15051
# Bash/Shell    13838
# Kotlin        10577
# C              9534
# PHP            8754
# Dart           6964
# Swift          6285
# Ruby           4883
# PowerShell     4824
# R              3958
# dtype: int64

# %%
plt.figure(figsize = (15,8))
plt.xticks(rotation = 80)
plt.title(' Popular Languages in past years ')
sns.barplot(y = popular_languages.index, x = popular_languages);
plt.xlabel('Count')
plt.ylabel('Languages');

# %% [markdown]
# ##### - As we can see `JavaScript` and `Python` are among the top most used language and their demand also increasing day by day , so this number can only increase in near future.
# ##### - Also it can be seen that the popularity of `TypeScript` is increasing day by day and alredy used by so many developers.

# %% [markdown]
# ## Q. What are the most common languages used by developers older than 35 years of age?

# %%
# Developers above 35 years old
exp_developers_df = stackoverflow21[stackoverflow21.Age>35]
exp_developers_df.head()
# Out:
#                                               Country   Age Gender  \
# 14  United Kingdom of Great Britain and Northern I...  45.0    Man
# 18                                          Singapore  45.0    Man
# 27  United Kingdom of Great Britain and Northern I...  45.0    Man
# 47                           United States of America  65.0    Man
# 71                           United States of America  45.0    Man
#
#                                             EdLevel     Age1stCode  \
# 14     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 18       Other doctoral degree (Ph.D., Ed.D., etc.)  11 - 17 years
# 27     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 47     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 71  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  18 - 24 years
#
#                   LearnCode  YearsCode  YearsCodePro  \
# 14                   School       40.0           NaN
# ...

# %%
# Lanuages used by experienced developers
oldage_languages = split_multicolumn(exp_developers_df.Language)
oldage_languages.head()
# Out:
#     JavaScript    PHP    SQL    C++  Python  Bash/Shell   Java     Go  \
# 14        True   True   True  False   False       False  False  False
# 18       False  False  False   True    True       False  False  False
# 27       False  False   True  False    True        True  False  False
# 47       False  False  False  False   False       False   True  False
# 71        True  False   True  False   False       False   True   True
#
#     HTML/CSS  Node.js  ...    APL  Erlang  Groovy    VBA  Elixir   Ruby  \
# 14     False    False  ...  False   False   False  False   False  False
# 18     False    False  ...  False   False   False  False   False  False
# 27     False    False  ...  False   False   False  False   False  False
# 47     False    False  ...  False   False   False  False   False  False
# 71      True     True  ...  False   False   False  False   False  False
#
#     Objective-C  Scala  Crystal  COBOL
# 14        False  False    False  False
# ...

# %%
oldage_popular_languages = oldage_languages.sum().sort_values(ascending = False).head(20)
oldage_popular_languages
# Out:
# JavaScript    2923
# SQL           2804
# Python        2574
# HTML/CSS      2477
# C#            1831
# TypeScript    1744
# Bash/Shell    1496
# Node.js       1433
# Java          1308
# C++           1066
# Rust          1030
# Go             961
# C              871
# PHP            747
# PowerShell     635
# Kotlin         623
# Swift          523
# Delphi         470
# Ruby           434
# R              433
# dtype: int64

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation = 80)
plt.title('Popular languages among experienced people')
sns.barplot(y = oldage_popular_languages.index, x = oldage_popular_languages);
plt.xlabel('Count')
plt.ylabel('Languages');

# %% [markdown]
# ##### As it can be seen in case of experience developers also `JavaScript` still remains at the top but `SQL` comes from behind to take 2nd spot  after JS, surpassing Python.

# %% [markdown]
# ## Q. What are the most common languages used by developers in your home country?

# %%
home_dev = stackoverflow21[stackoverflow21.Country == 'India']
home_dev.head()
# Out:
#    Country Age Gender                                            EdLevel  \
# 8    India  25    Man       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 22   India  18    Man  Some college/university study without earning ...
# 39   India  18  Woman       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49   India  18    Man  Some college/university study without earning ...
# 52   India  25    Man    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#    Age1stCode                                          LearnCode YearsCode  \
# 8     18 - 24                                    Coding Bootcamp         6
# 22        NaN                     School;Friend or family member         7
# 39    11 - 17                                             School         3
# 49    11 - 17  Coding Bootcamp;Other online resources (ex: vi...       NaN
# 52    11 - 17  Other online resources (ex: videos, blogs, etc...         5
#
#    YearsCodePro                                           Language  \
# ...

# %%
home_dev_languages = split_multicolumn(home_dev.Language)
home_dev_languages.head()
# Out:
#     HTML/CSS  JavaScript   Java  Kotlin  Python   Dart  Elixir     Go    SQL  \
# 8       True        True  False   False   False  False   False  False  False
# 22     False       False   True    True    True  False   False  False  False
# 39     False       False  False   False   False  False   False  False  False
# 49     False       False  False   False   False   True    True   True   True
# 52      True        True  False   False    True  False   False  False  False
#
#     Node.js  ...  Groovy  Crystal  Matlab  Clojure  Haskell  Erlang    APL  \
# 8     False  ...   False    False   False    False    False   False  False
# 22    False  ...   False    False   False    False    False   False  False
# 39    False  ...   False    False   False    False    False   False  False
# 49    False  ...   False    False   False    False    False   False  False
# 52     True  ...   False    False   False    False    False   False  False
#
#      LISP  COBOL  Delphi
# 8   False  False   False
# ...

# %%
hometown_languages = home_dev_languages.sum().sort_values(ascending = False).head(20)
hometown_languages
# Out:
# JavaScript    5220
# Python        5191
# Node.js       3855
# HTML/CSS      3629
# SQL           3185
# TypeScript    3126
# Java          3058
# Go            2235
# C++           2077
# Kotlin        1669
# Dart          1414
# C#            1306
# C             1215
# Bash/Shell    1195
# Rust          1149
# PHP           1045
# Swift          858
# R              711
# Ruby           501
# PowerShell     474
# dtype: int64

# %%
plt.figure(figsize = (12,7))
plt.xticks(rotation = 80)
plt.title('Most popular languages in India')
sns.barplot(y = hometown_languages.index , x = hometown_languages)
plt.xlabel('Count');

# %% [markdown]
# ##### i) As we can see wheather developers from 'whole world' , 'developer from India' (Home Town) or among the 'most experience' developer, now a days most common languages to work with are `JavaScript` and `Python`.
# ##### ii) Also the web developement technologies are most popular as stackoverflow is mostly used by the Full-stack Web developer
# ##### iii) And only `SQL` which is not among web tech mainly used for quaring data is featured among top 5 .

# %% [markdown]
# # Database

# %%
stackoverflow21.Database
# Out:
# 0                                       PostgreSQL;SQLite
# 1                                              PostgreSQL
# 2                                                  SQLite
# 3                                                     NaN
# 4                          Elasticsearch;PostgreSQL;Redis
#                                ...
# 83434                                       Oracle;SQLite
# 83435      Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436     DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437    Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                   Oracle;PostgreSQL
# Name: Database, Length: 83439, dtype: object

# %%
database_type = split_multicolumn(stackoverflow21.Database)
database_type.head()
# Out:
#    PostgreSQL  SQLite  Elasticsearch  Redis  MySQL  Microsoft SQL Server  \
# 0        True    True          False  False  False                 False
# 1        True   False          False  False  False                 False
# 2       False    True          False  False  False                 False
# 3       False   False          False  False  False                 False
# 4        True   False           True   True  False                 False
#
#    Oracle  MongoDB  MariaDB  DynamoDB  Couchbase  Firebase  Cassandra  IBM DB2
# 0   False    False    False     False      False     False      False    False
# 1   False    False    False     False      False     False      False    False
# 2   False    False    False     False      False     False      False    False
# 3   False    False    False     False      False     False      False    False
# 4   False    False    False     False      False     False      False    False

# %%
popular_databases = database_type.sum().sort_values(ascending = False)
popular_databases
# Out:
# MySQL                   35289
# PostgreSQL              28424
# SQLite                  22634
# MongoDB                 19479
# Microsoft SQL Server    18896
# Redis                   14552
# MariaDB                 12088
# Firebase                11373
# Elasticsearch            9331
# Oracle                   8868
# DynamoDB                 5137
# Cassandra                1873
# IBM DB2                  1438
# Couchbase                1106
# dtype: int64

# %%
plt.figure(figsize = (12,6))
plt.xticks(rotation = 80)
plt.title("Popular Database's in past years")
sns.barplot(y = popular_databases , x = popular_databases.index ,color = 'violet');

# %% [markdown]
# ##### According to the responces of the developers  `MySQL` has been chosen to be the most popular/used database accross globe over the last  few years, following that there is `PostgreSQL`.
# ##### But when it comes to No-sql databases then `MongoDB` is most popular among all .

# %% [markdown]
# ## Webframe

# %%
stackoverflow21.Webframe
# Out:
# 0                                     Laravel;Symfony
# 1                                Angular;Flask;Vue.js
# 2                                               Flask
# 3                                      Angular;jQuery
# 4                                               Flask
#                              ...
# 83434                                             NaN
# 83435    Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                   FastAPI;Flask
# 83437                   Django;Express;Flask;React.js
# 83438                                  Angular;Spring
# Name: Webframe, Length: 83439, dtype: object

# %%
webframe_type = split_multicolumn(stackoverflow21.Webframe)
webframe_type.head()
# Out:
#    Laravel  Symfony  Angular  Flask  Vue.js  jQuery  Express  React.js  \
# 0     True     True    False  False   False   False    False     False
# 1    False    False     True   True    True   False    False     False
# 2    False    False    False   True   False   False    False     False
# 3    False    False     True  False   False    True    False     False
# 4    False    False    False   True   False   False    False     False
#
#    Angular.js  Ruby on Rails  Django  FastAPI  ASP.NET Core   Spring  Svelte  \
# 0       False          False   False    False          False   False   False
# 1       False          False   False    False          False   False   False
# 2       False          False   False    False          False   False   False
# 3       False          False   False    False          False   False   False
# 4       False          False   False    False          False   False   False
#
#    ASP.NET  Gatsby  Drupal
# 0    False   False   False
# ...

# %%
popular_webframes = webframe_type.sum().sort_values(ascending = False).head(15)
popular_webframes
# Out:
# React.js         25296
# jQuery           21693
# Express          15010
# Angular          14471
# Vue.js           11954
# ASP.NET Core     11404
# Flask            10174
# ASP.NET           9918
# Django            9446
# Spring            9177
# Angular.js        7242
# Laravel           6377
# Ruby on Rails     4438
# Gatsby            2501
# FastAPI           2447
# dtype: int64

# %%
plt.figure(figsize = (12,6))
plt.xticks(rotation = 80)
sns.barplot(y = popular_webframes , x = popular_webframes.index, color ='b')
plt.title('Popular Webframes from past few years');

# %% [markdown]
# ##### As the demand for full-stack developers increasing day by day , the languages/webframes used in those jobs also increasing rapidly that can also judged by this graph as `React.js`,`Angular`,`Vue.js` all the possible front-end frameworks are at the top , where as for the backend the python frameworks like `Flask` and `Django` is in high demand .

# %% [markdown]
# # Cloud Platforms

# %%
stackoverflow21.Platform
# Out:
# 0                              NaN
# 1                              NaN
# 2                           Heroku
# 3                              NaN
# 4                              NaN
#                    ...
# 83434                          AWS
# 83435                          NaN
# 83436    AWS;Google Cloud Platform
# 83437                       Heroku
# 83438              Microsoft Azure
# Name: Platform, Length: 83439, dtype: object

# %%
platform_types = split_multicolumn(stackoverflow21.Platform)
platform_types
# Out:
#        Heroku  Microsoft Azure    AWS  Google Cloud Platform  DigitalOcean  \
# 0       False            False  False                  False         False
# 1       False            False  False                  False         False
# 2        True            False  False                  False         False
# 3       False            False  False                  False         False
# 4       False            False  False                  False         False
# ...       ...              ...    ...                    ...           ...
# 83434   False            False   True                  False         False
# 83435   False            False  False                  False         False
# 83436   False            False   True                   True         False
# 83437    True            False  False                  False         False
# 83438   False             True  False                  False         False
#
#        Oracle Cloud Infrastructure  IBM Cloud or Watson
# ...

# %%
popular_cloud = platform_types.sum().sort_values(ascending = False)
popular_cloud
# Out:
# AWS                            29138
# Google Cloud Platform          16687
# Microsoft Azure                16540
# Heroku                         12897
# DigitalOcean                    9495
# IBM Cloud or Watson             1373
# Oracle Cloud Infrastructure     1014
# dtype: int64

# %%
plt.figure(figsize = (12,6))
plt.xticks(rotation = 80)
sns.barplot(y = popular_cloud , x = popular_cloud.index , color='crimson')
plt.title('Popular Cloud Platforms from past few years');

# %% [markdown]
# ##### `AWS!!!!!` Amazon Web Services undoubtedly is the most popular cloud plateform in the globe, that is replicated in this graphical representation also .Other than that also `GCP` and `MS Azure` are in among the top 3 best cloud platform.

# %% [markdown]
# # Operating System

# %%
stackoverflow21.OpSys
# Out:
# 0              MacOS
# 1            Windows
# 2              MacOS
# 3            Windows
# 4        Linux-based
#             ...
# 83434          MacOS
# 83435    Linux-based
# 83436        Windows
# 83437          MacOS
# 83438    Linux-based
# Name: OpSys, Length: 83439, dtype: object

# %%
popular_opsys = stackoverflow21.OpSys.value_counts()
popular_opsys
# Out:
# Windows                              37758
# Linux-based                          21088
# MacOS                                20984
# Windows Subsystem for Linux (WSL)     2743
# Other (please specify):                575
# BSD                                    146
# Name: OpSys, dtype: int64

# %%
plt.figure(figsize = (12,6))
plt.xticks(rotation = 80)
plt.title('Popular Operating system used by respondants from past few years')
sns.barplot(x = popular_opsys , y = popular_opsys.index);

# %% [markdown]
# ##### Due to the price and accessibility `Windows` is the most commonly used operating system whereas `MacOS` also gaining its popularity over the years, as the user/developer usage of MacOS is currently close to Linux OS.

# %% [markdown]
# # Learning Medium

# %%
# 'How did you learn to code?'
stackoverflow21.LearnCode
# Out:
# 0        Coding Bootcamp;Other online resources (ex: vi...
# 1        Other online resources (ex: videos, blogs, etc...
# 2        Other online resources (ex: videos, blogs, etc...
# 3                                                      NaN
# 4                                  Friend or family member
#                                ...
# 83434    Other online resources (ex: videos, blogs, etc...
# 83435    Other online resources (ex: videos, blogs, etc...
# 83436                                               School
# 83437    Online Courses or Certification;Books / Physic...
# 83438                                               School
# Name: LearnCode, Length: 83439, dtype: object

# %%
learning_medium = split_multicolumn(stackoverflow21.LearnCode)
learning_medium
# Out:
#        Coding Bootcamp  Other online resources (ex: videos, blogs, etc)  \
# 0                 True                                             True
# 1                False                                             True
# 2                False                                             True
# 3                False                                            False
# 4                False                                            False
# ...                ...                                              ...
# 83434            False                                             True
# 83435            False                                             True
# 83436            False                                            False
# 83437            False                                            False
# 83438            False                                            False
#
#        School  Online Forum  Friend or family member  \
# ...

# %%
top_learn_medium = learning_medium.sum().sort_values(ascending = False)
top_learn_medium
# Out:
# Other online resources (ex: videos, blogs, etc)    49392
# School                                             44462
# Books / Physical media                             42752
# Online Courses or Certification                    33511
# Online Forum                                       26229
# Friend or family member                            15162
# Colleague                                          14225
# Coding Bootcamp                                     8496
# Other (please specify):                             6924
# dtype: int64

# %%
plt.figure(figsize = (12,6))
plt.xticks(rotation = 80)
plt.title('Popular resourses to gain knowledge')
sns.barplot(x = top_learn_medium , y = top_learn_medium.index);

# %% [markdown]
# ##### There is no surprice specially after the worldwide lockdown with high speed internet that theres almost every person gained numerious knowledge from `online videos and blogs`.
# ##### And wheather its coding or any other knowledge school is the 1st place to learn as there are huge chunk of people who started there dev/coding journey from `school`, so the percentage also remain very high.
# ##### Now if we talk about `books` , that can't be replaced even after all the online stuff the books remains at one of the top position and at top priority.

# %% [markdown]
# ## Yearly Salary

# %%
stackoverflow21.CompTotal.sort_values(ascending = False)
# Out:
# 66910    45241312.0
# 40586    21822250.0
# 28791    20000000.0
# 12700    19200000.0
# 9608     17500000.0
#             ...
# 83414           NaN
# 83417           NaN
# 83418           NaN
# 83426           NaN
# 83429           NaN
# Name: CompTotal, Length: 83439, dtype: float64

# %%
plt.scatter(y = stackoverflow21.CompTotal, x = stackoverflow21.YearsCodePro)
plt.xlabel('Professional Experiece in year')
plt.ylabel('Yearly Salary');

# %% [markdown]
# ##### From the above representation we can have an idea how the salary varry with respect to experience in coding profession.
# ##### But point to be noted here,  in this visualization we did'nt consider the salary based on their devtype as for different devtype / job-role the salary varries.

# %% [markdown]
# ## Inferences and Conclusions

# %% [markdown]
# Based on the 2021 survey we come to some conclusions that:
#
#    - From the demographical point of view mostly english speaking countries has responded more but still the community tends to more diversified.
#
#    - Aging factor of coder is one of the positive sign as mostly young and some mid-age people are engaging more and learning new tech skills over the years, lots of them started their professional career also very early.
#
#    - Although in terms of gender, the community is not diverse at all mostly the community is filled with higher no. of mens compared to others.
#
#    - Also the survey shows, to land a good job there is no higher level degrees needed, only bachelor degree or masters degree is enough.
#
#    - Javasript and Python are the most used languages, followed by SQL and HTML/CSS. Also Typescript is gaining its popularity at very rapid pace specially full-stack developer currently using it now very often.
#
#    - AWS emarging as the most importent skill without respect to any domain, now a days cloud is needed for almost everything and AWS currently the master of that market surpassing GCP and Azure.
#
#    - Learning new skills and gining knowledge will be even more easier with the increase of internet accesebility, in future days also online videos and blog will be there as top resourses, also Podcasts also can play a big part of these learnings in future.

# %% [markdown]
# ## References

# %% [markdown]
# Some of the important references used during this project:
#
# - Stack Overflow Developer Survey: https://insights.stackoverflow.com/survey
#
# - Jovian Notebook Reference: https://jovian.ai/aakashns/stackoverflow-survey-exploratory-data-analysis
#
# - Pandas user guide: https://pandas.pydata.org/docs/user_guide/index.html
#
# - Matplotlib user guide: https://matplotlib.org/3.3.1/users/index.html
#
# - Seaborn user guide & tutorial: https://seaborn.pydata.org/tutorial.html

# %% [markdown]
#                                                                                                     @ Saptaswa Basu_06/2022
